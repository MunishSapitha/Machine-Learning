# %%
# import pandas library

import pandas as pd

# %%
# load dataset

dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
# Categorical input data
# Nominal - one hot encoding

dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#split input data

independent=dataset[['age', 'bmi', 'children',  'sex_male','smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
# split output data

dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
# Split training and testing data

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
# Standardization

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
# Model Creation - SVM
# kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’} or callable, default=’rbf’
# C: float, default=1.0

# gridsearch and cross validation Model  Creation

# class sklearn.model_selection.GridSearchCV(estimator, param_grid, *, scoring=None, n_jobs=None, refit=True, cv=None, verbose=0, pre_dispatch='2*n_jobs', error_score=nan, return_train_score=False)
from sklearn.model_selection import GridSearchCV

from sklearn.svm import SVR

#Python dictionaries - are used to store data values in key:value pairs

param_grid={'kernel':['linear','rbf','poly','sigmoid'],
             'C':[10,100,1000,2000,3000],
             'gamma':['auto','scale']}

grid=GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1)


grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# F:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              verbose=3)

# %%
# Print hyper tuning parameter and r2_score


#cv_results_ - sklearn attributes
# convert the table into dictionary fornat
# A dictionary with keys- column headers and values as columns

result=grid.cv_results_

# Evaluation Metrics

y_pred=grid.predict(x_test)

# r2_score

# best_params_ - sklearn attributes
# parameter gave the best results only if refit is specified

# format method in python - formats the specified value and insert them inside the string placeholders
# format placeholders is defined using {}


from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
print("The r2_score with hyper tuning parameter : {} " .format(grid.best_params_) ,r_score)
# Out:
# The r2_score with hyper tuning parameter : {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}  0.859893008449439

# %%
# view in Table Format

# pandas data frame is a 2D two dimensional data structure like two dimensional array
# dataframe - a table with rows and columns

# from_dict() - create a pandas dataframe from python dictionary

table=pd.DataFrame.from_dict(result)
table

#rank test_score - 1 gives the best result
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.341444      0.080847         0.040399        0.006399      10
# 1        0.214905      0.012822         0.111462        0.003526      10
# 2        0.171255      0.005454         0.041895        0.011468      10
# 3        0.233280      0.018434         0.046052        0.005785      10
# 4        0.178913      0.010636         0.030078        0.004245      10
# 5        0.216184      0.008779         0.111048        0.010427      10
# 6        0.169146      0.004118         0.037775        0.006705      10
# 7        0.276280      0.015425         0.055860        0.013222      10
# 8        0.257133      0.030198         0.032718        0.003088     100
# 9        0.203727      0.006909         0.110855        0.006327     100
# 10       0.191242      0.011633         0.037706        0.009759     100
# 11       0.241083      0.008410         0.045047        0.006671     100
# 12       0.225309      0.012593         0.034779        0.002853     100
# 13       0.220380      0.010703         0.118094        0.014524     100
# 14       0.196516      0.018254         0.033300        0.002492     100
# 15       0.216071      0.006201         0.044578        0.006923     100
# 16       0.239521      0.018741         0.031354        0.005082    1000
# 17       0.271347      0.018398         0.113948        0.011701    1000
# 18       0.270811      0.052208         0.037519        0.005469    1000
# 19       0.256636      0.015282         0.045265        0.003618    1000
# 20       0.249291      0.013092         0.034258        0.003393    1000
# 21       0.271197      0.012609         0.113725        0.006978    1000
# 22       0.286596      0.070650         0.036133        0.007820    1000
# 23       0.241248      0.012000         0.042399        0.006502    1000
# 24       0.286594      0.033106         0.030086        0.002074    2000
# 25       0.282710      0.025838         0.109398        0.005519    2000
# 26       0.452112      0.103523         0.033639        0.007783    2000
# 27       0.275087      0.020278         0.045953        0.007402    2000
# 28       0.281608      0.016225         0.030814        0.002237    2000
# 29       0.289648      0.005926         0.115371        0.008893    2000
# 30       0.415289      0.026814         0.033788        0.003755    2000
# 31       0.262693      0.013090         0.046442        0.009380    2000
# 32       0.357821      0.019862         0.031250        0.002783    3000
# 33       0.315096      0.009639         0.115506        0.005779    3000
# 34       0.803097      0.361772         0.041419        0.006884    3000
# 35       0.264992      0.017972         0.043890        0.004430    3000
# 36       0.349704      0.026085         0.030718        0.005833    3000
# 37       0.320629      0.018877         0.100110        0.003755    3000
# 38       0.834777      0.371405         0.032290        0.004032    3000
# 39       0.257420      0.038670         0.040444        0.004729    3000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto         poly
# 3         auto      sigmoid
# 4        scale       linear
# 5        scale          rbf
# 6        scale         poly
# 7        scale      sigmoid
# 8         auto       linear
# 9         auto          rbf
# 10        auto         poly
# 11        auto      sigmoid
# 12       scale       linear
# 13       scale          rbf
# 14       scale         poly
# 15       scale      sigmoid
# 16        auto       linear
# 17        auto          rbf
# 18        auto         poly
# 19        auto      sigmoid
# 20       scale       linear
# 21       scale          rbf
# 22       scale         poly
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto          rbf
# 26        auto         poly
# 27        auto      sigmoid
# 28       scale       linear
# 29       scale          rbf
# 30       scale         poly
# 31       scale      sigmoid
# 32        auto       linear
# 33        auto          rbf
# 34        auto         poly
# 35        auto      sigmoid
# 36       scale       linear
# 37       scale          rbf
# 38       scale         poly
# 39       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.377969
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.004055
# 2        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.056274
# 3     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.049905
# 4     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.377969
# 5        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.004126
# 6       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.054964
# 7    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.049644
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584474
# 9        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300573
# 10      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.540643
# 11   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.478364
# 12   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.584474
# 13      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.301041
# 14     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.537117
# 15  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.478930
# 16   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.605304
# 17      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.733044
# 18     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.829631
# 19  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.296082
# 20  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.605304
# 21     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.733334
# 22    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.828213
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.400044
# 24   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.605277
# 25      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.814076
# 26     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.845403
# 27  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.401855
# 28  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.605277
# 29     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.814295
# 30    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.845581
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.385658
# 32   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.657470
# 33      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.828670
# 34     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.846775
# 35  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.090896
# 36  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.657470
# 37     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.828795
# 38    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.846874
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.761871
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.479601           0.317872           0.337979
# 1            0.013366          -0.103821          -0.095119
# 2            0.069532          -0.045601          -0.025079
# 3            0.075905          -0.046585          -0.041004
# 4            0.479601           0.317872           0.337979
# 5            0.013244          -0.103775          -0.095165
# 6            0.071297          -0.046513          -0.024157
# 7            0.076323          -0.046798          -0.040824
# 8            0.655818           0.553380           0.576939
# 9            0.339474           0.173708           0.217991
# 10           0.575051           0.474839           0.535730
# 11           0.561673           0.428331           0.450454
# 12           0.655818           0.553380           0.576939
# 13           0.338741           0.174086           0.217641
# 14           0.579373           0.471840           0.537966
# 15           0.563200           0.427152           0.451250
# 16           0.588725           0.623230           0.537931
# 17           0.746232           0.686773           0.717920
# 18           0.802622           0.799620           0.800321
# 19           0.372281           0.216401           0.291265
# 20           0.588725           0.623230           0.537931
# 21           0.745892           0.687037           0.717769
# 22           0.802622           0.799348           0.800587
# 23           0.366097           0.242217           0.288461
# 24           0.583646           0.697368           0.532547
# 25           0.781092           0.794081           0.794075
# 26           0.805639           0.816733           0.805143
# 27          -0.508082          -0.452827          -0.751013
# 28           0.583646           0.697368           0.532547
# 29           0.780971           0.794227           0.793983
# 30           0.805624           0.816612           0.805133
# 31          -0.537098          -0.474912          -0.477335
# 32           0.583501           0.697875           0.529117
# 33           0.790265           0.811049           0.812892
# 34           0.805323           0.817309           0.805191
# 35          -1.761043          -1.734344          -2.304377
# 36           0.583501           0.697875           0.529117
# 37           0.790105           0.811123           0.812857
# 38           0.805331           0.817283           0.805239
# 39          -2.139307          -1.704369          -2.340839
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.324422         0.367569        0.059777               25
# 1           -0.101604        -0.056625        0.053504               35
# 2           -0.049592         0.001107        0.051309               32
# 3           -0.046507        -0.001657        0.053391               34
# 4            0.324422         0.367569        0.059777               25
# 5           -0.101602        -0.056634        0.053486               36
# 6           -0.049652         0.001188        0.051594               31
# 7           -0.046521        -0.001635        0.053474               33
# 8            0.546881         0.583498        0.038787               19
# 9            0.183375         0.243024        0.065733               29
# 10           0.424640         0.510181        0.053582               21
# 11           0.431701         0.470105        0.049110               24
# 12           0.546881         0.583498        0.038787               19
# 13           0.183403         0.242982        0.065542               30
# 14           0.424478         0.510155        0.054955               22
# 15           0.432199         0.470546        0.049762               23
# 16           0.616726         0.594383        0.030560               17
# 17           0.649158         0.706625        0.034902               12
# 18           0.735580         0.793555        0.031072                7
# 19           0.351325         0.305471        0.054387               28
# 20           0.616726         0.594383        0.030560               17
# 21           0.649174         0.706641        0.034825               11
# 22           0.735555         0.793265        0.030757                8
# 23           0.351407         0.329645        0.056742               27
# 24           0.681425         0.620053        0.061555               15
# 25           0.733656         0.783396        0.027014               10
# 26           0.754961         0.805576        0.029233                4
# 27          -0.111859        -0.445127        0.205197               38
# 28           0.681425         0.620053        0.061555               15
# 29           0.733663         0.783428        0.027068                9
# 30           0.754962         0.805582        0.029272                3
# 31          -0.111187        -0.397238        0.150976               37
# 32           0.655785         0.624750        0.060379               13
# 33           0.741829         0.796941        0.030140                6
# 34           0.758994         0.806718        0.028279                2
# 35          -1.050280        -1.588188        0.469215               39
# 36           0.655785         0.624750        0.060379               13
# 37           0.741835         0.796943        0.030174                5
# 38           0.758988         0.806743        0.028307                1
# 39          -1.048739        -1.799025        0.443311               40

# %%
#Output from EndUser

age=float(input("Age :"))
bmi=float(input("BMI :"))
children=int(input("Children :"))
sex_male=int(input("Sex_male 1 or 0 :"))
smoker_yes=int(input("Smoker 1 0r 0 :"))
# Out:
# Age :23
# BMI :34
# Children :2
# Sex_male 1 or 0 :0
# Smoker 1 0r 0 :0

# %%
#Output Prediction

Prediction=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future Prediction {} ".format(Prediction))
# Out:
# Future Prediction [672636.24550213]
